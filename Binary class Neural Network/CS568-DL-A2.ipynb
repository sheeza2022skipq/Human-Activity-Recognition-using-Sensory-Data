# %% [markdown]
# # <center>CS568:Deep Learning</center>  <center>Fall 2020</center>

# %% [markdown]
# ## Assignment 2
#
# **Total Marks: 100**
#
# **Assigned**:  Saturday, February 20, 2021
#
# **Due**: Saturday, February 27, 2021 before **11.00 PM**
#
# ## a) Initialization
#
# Train a neural network for multi-class classification and fill the table given below. **(50 marks)**
# + dataset = MNIST
# + layers = [784, 50, 10]
# + activations = [None, sigmoid, softmax]
# + batch size = 100
# + epochs = 10
# + learning rate = 1e-3
# + optimizer = stochastic gradient descent
# + loss function = cross-entropy
#
# <table>
#     <tr>
#         <td>
#         <b>Initialization</b>
#         </td>
#         <td>
#         <b>Train accuracy</b>
#         </td>
#           <td>
#         <b>Test accuracy</b>
#         </td>
#     <tr>
#         <td>
#        Random initialization (np.random.randn)
#         </td>
#         <td>
#         19.5104%
#         </td>
#         <td>
#          19.37%
#         </td>
#     </tr>
#     <tr>
#         <td>
#        Random initialization  and c=10
#         </td>
#         <td>
#         11.3438%
#         </td>
#          <td>
#          11.38%
#         </td>
#     </tr>
#      <tr>
#         <td>
#         Xavier initialization
#         </td>
#         <td>
#          80.0021%
#         </td>
#          <td>
#          80.6%
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## b) Optimizer
#
# Train a neural network for multi-class classification and fill the table given below. **(50 marks)**
# + dataset = MNIST
# + initialization = Xavier
# + layers = [784, 50, 10]
# + activations = [None, sigmoid, softmax]
# + batch size = 100
# + epochs = 10
# + learning rate = 1e-3
# + loss function = cross-entropy
#
# <table>
#     <tr>
#         <td>
#         <b>Optimization method</b>
#         </td>
#         <td>
#         <b>Train accuracy</b>
#         </td>
#           <td>
#         <b>Test accuracy</b>
#         </td>
#     </tr>
#         <td>
#         Stochastic Gradient Descent
#         </td>
#         <td>
#          80.0021%
#         </td>
#         <td>
#          80.6%
#         </td>
#     <tr>
#         <td>
#        Momentum
#         </td>
#         <td>
#         80.0438%
#         </td>
#          <td>
#         80.69%
#         </td>
#     </tr>
#      <tr>
#         <td>
#         Adam
#         </td>
#         <td>
#         88.0729%
#         </td>
#          <td>
#          88.37%
#         </td>
#     </tr>
# </table>
